# %% [markdown]
# # Data Analytics Starter Notebook
#
# This notebook is a simple template you can upload to GitHub.
#
# **Author:** Ram Sudhakar Varma
#
# **Purpose:** Practice Python, Pandas, and basic data analysis.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np

print('Libraries imported successfully')

# %% [markdown]
# ## 2. Create Sample Data

# %%
data = {
    'Name': ['A', 'B', 'C', 'D'],
    'Score': [85, 90, np.nan, 88],
    'Department': ['IT', 'CSE', 'IT', 'ECE']
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## 3. Basic Data Exploration

# %%
df.head()

df.info()

df.describe(include='all')

# %% [markdown]
# ## 4. Handling Missing Values

# %%
df['Score'] = df['Score'].fillna(df['Score'].mean())
df

# %% [markdown]
# ## 5. Simple Analysis

# %%
avg_score_by_dept = df.groupby('Department')['Score'].mean()
avg_score_by_dept

# %% [markdown]
# ## 6. Conclusion
#
# This notebook demonstrates basic data analytics steps using Pandas.
# You can extend this with visualization, ML models, or real datasets.
